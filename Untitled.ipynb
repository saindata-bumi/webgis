# %%
# !eval 'ssh-agent -s'
# Out:
# SSH_AUTH_SOCK=/tmp/ssh-XXXXXXeE4l37/agent.4856; export SSH_AUTH_SOCK;
# SSH_AGENT_PID=4857; export SSH_AGENT_PID;
# echo Agent pid 4857;

# %%
# !eval 'ssh-agent -s'
# Out:
# SSH_AUTH_SOCK=/tmp/ssh-XXXXXXvckTTq/agent.4981; export SSH_AUTH_SOCK;
# SSH_AGENT_PID=4982; export SSH_AGENT_PID;
# echo Agent pid 4982;

# %%
# !git remote set-url origin git@github.com:saindata-bumi/webgis.git

# %%
# !ssh-add ~/.ssh/id_rsa
# Out:
# Could not open a connection to your authentication agent.

# %%
# !ssh -T git@github.com
# Out:
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @         WARNING: UNPROTECTED PRIVATE KEY FILE!          @
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Permissions 0660 for '/home/jovyan/.ssh/id_ed25519' are too open.
# It is required that your private key files are NOT accessible by others.
# This private key will be ignored.
# Load key "/home/jovyan/.ssh/id_ed25519": bad permissions
# git@github.com: Permission denied (publickey).

# %%
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-64443082
